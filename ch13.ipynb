# %%
import turtle
class My(turtle.Turtle):
    def __init__(self, speed=1):
        turtle.Turtle.__init__(self)
        self.penup()
        self.shape('turtle')
        self.pencolor('green')
        self.speed=speed
    def up(self):
        self.setheading(90)
    def down(self):
        self.setheading(270)
    def left(self):
        self.seth(180)
    def right(self):
        self.seth(0)
    def move(self):
        self.forward(self.speed)
        
s=turtle.Screen()
s.title('project game')
my = My(0.1)
turtle.onkeypress(my.up,"Up")
turtle.onkeypress(my.down,"Down")
turtle.onkeypress(my.left,"Left")
turtle.onkeypress(my.right,"Right")
turtle.listen()#keypress누른걸 감지하도록 함
s.tracer(0)
while True:
    s.update()
    my.move()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 22
#      20 s=turtle.Screen()
#      21 s.title('project game')
# ---> 22 my = My(0.1)
#      23 turtle.onkeypress(my.up,"Up")
#      24 turtle.onkeypress(my.down,"Down")
#
# Cell In[2], line 4, in My.__init__(self, speed)
#       3 def __init__(self, speed=1):
# ----> 4     turtle.Turtle.__init__(self)
#       5     self.penup()
#       6     self.shape('turtle')
#
# File ~\Contacts\anaconda3\Lib\turtle.py:3845, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3843 if Turtle._screen is None:
#    3844     Turtle._screen = Screen()
# -> 3845 RawTurtle.__init__(self, Turtle._screen,
#    3846                    shape=shape,
#    3847                    undobuffersize=undobuffersize,
#    3848                    visible=visible)
#
# ...

# %%
import turtle
class My(turtle.Turtle):
    def __init__(self, speed=1):
        turtle.Turtle.__init__(self)
        self.penup()
        self.shape('turtle')
        self.pencolor('green')
        self.speed=speed
    def up(self):
        self.setheading(90)
    def down(self):
        self.setheading(270)
    def left(self):
        self.seth(180)
    def right(self):
        self.seth(0)
    def move(self):
        self.forward(self.speed)
        
s=turtle.Screen()
s.title('project game')
my = My(0.1)
turtle.onkeypress(my.up,"Up")
turtle.onkeypress(my.down,"Down")
turtle.onkeypress(my.left,"Left")
turtle.onkeypress(my.right,"Right")
turtle.listen()#keypress누른걸 감지하도록 함
s.tracer(0)
while True:
    s.update()
    my.move()

import random
colors = ['beige', 'yellow', 'pink', 'orange', 'red', 'black']
class Enemy(turtle.Turtle):
    def __init__(self,speed=1):
        turtle.Turtle.__init__(self)
        self.penup()
        self.color(colors[random.randint(0,5)])
        self.shape('turtle')
        self.speed = speed
        self.goto(random.randint(-250,250), random.randint(-250,250))

    def move(self):
        self.forward(self.speed)
        if random.randint(1,1000)==1:
            self.seth(self.towards(my))
enemy = Enemy(0.2)
while True:
    enemy.move()
